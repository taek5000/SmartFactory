# %% [markdown]
# # 라이브러리/데이터 불러오기

# %% [markdown]
# ## 패키지 불러오기

# %%
# 필요 패키지 불러오기
import pandas as pd
import numpy as np

# %% [markdown]
# ## 데이터 불러오기

# %%
# 데이터 불러오기 및 상단 5개 데이터 확인
df = pd.read_csv('C:\\Users\\taek5\\Desktop\\TG\\SmartFactory\\data\\HeatTreatmentQualityAssurance\\data.csv', encoding = 'cp949')
df.head()
# Out:
#                TAG_MIN    배정번호  건조 1존 OP  건조 2존 OP  건조로 온도 1 Zone  \
# 0  2022-01-03 11:22:07  102410   75.6648   30.0155            NaN
# 1  2022-01-03 11:22:08  102410   75.6706   32.2732            NaN
# 2  2022-01-03 11:22:09  102410   75.6776   32.1592        98.8533
# 3  2022-01-03 11:22:11  102410   75.8656   30.8312        98.7918
# 4  2022-01-03 11:22:12  102410   73.6468   29.5274        98.7918
#
#    건조로 온도 2 Zone     세정기  소입1존 OP  소입2존 OP  소입3존 OP  ...  소입로 CP 값  \
# 0            NaN 68.4386  72.8403  59.7862  51.7169  ...    0.4504
# 1            NaN 68.4386  78.4415  61.6286  50.4453  ...    0.4504
# 2        99.1460 68.4386  78.1099  61.5414  52.0196  ...    0.4503
# 3        99.1767 68.4999  77.5072  60.6663  52.6942  ...    0.4502
# 4        99.2075 68.4386  76.0262  61.1634  51.6915  ...    0.4502
#
#    소입로 CP 모니터 값  소입로 온도 1 Zone  소입로 온도 2 Zone  소입로 온도 3 Zone  소입로 온도 4 Zone  \
# 0           NaN            NaN       859.8540            NaN            NaN
# 1        0.0000       860.3380       859.7800       860.0440       859.7860
# 2        0.0000       860.3380       859.7800       859.9810       859.7240
# 3        0.0000       860.3380       859.8420       859.9500       859.5990
# 4        0.0000       860.3510       859.7910       859.9910       859.7310
#
#    솔트 컨베이어 온도 1 Zone  솔트 컨베이어 온도 2 Zone  솔트조 온도 1 Zone  솔트조 온도 2 Zone
# 0                NaN                NaN            NaN            NaN
# 1           294.6580           272.5380       328.7340       328.8650
# 2           294.6580           272.5380       328.7340       328.8050
# 3           294.7190           272.5380       328.6740       328.8650
# 4           294.7210           272.5990       328.7400       328.8080
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 참고사항 경고메시지 미노출

# %%
# 경고문구 제거 코드
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# # 데이터 탐색

# %% [markdown]
# ## 기초 통계 확인

# %%
# 지수표현 제거
pd.options.display.float_format = '{:.4f}'.format

# %%
# 지수표현 제거 후 데이터 통계치 확인
df.describe()
# Out:
#               배정번호     건조 1존 OP     건조 2존 OP  건조로 온도 1 Zone  건조로 온도 2 Zone  \
# count 2939722.0000 2939721.0000 2939721.0000   2939606.0000   2939574.0000
# mean   128442.2464      69.8940      20.4471       100.0061       100.0198
# std     12637.0445       4.0148       5.2171         0.4360         0.3624
# min    102410.0000      47.2532       0.0001        97.3421        97.8706
# 25%    119448.0000      68.4288      18.9176        99.8144        99.8901
# 50%    129889.0000      70.5166      21.2931       100.0020       100.0190
# 75%    139116.0000      72.3781      23.3884       100.1910       100.1610
# max    148069.0000      87.2995      47.5395       102.4690       101.8430
#
#                세정기      소입1존 OP      소입2존 OP      소입3존 OP      소입4존 OP  \
# count 2939631.0000 2935434.0000 2939722.0000 2939720.0000 2939719.0000
# mean       67.7186      75.6437      54.8624      53.8603      71.0893
# std         1.6308      25.1608       4.4291       2.6643       2.5570
# min        60.6244       0.0009       8.6200       0.0437       0.0062
# 25%        66.5694      64.9627      53.3259      52.3891      69.6781
# 50%        67.6972      82.2104      55.6654      53.8862      71.0454
# 75%        68.9799      95.3666      57.5733      55.4145      72.4771
# max        71.4901     100.0000      77.2709      66.0150      87.3907
#
#           소입로 CP 값  소입로 CP 모니터 값  소입로 온도 1 Zone  소입로 온도 2 Zone  소입로 온도 3 Zone  \
# count 2939721.0000  2939575.0000   2939592.0000   2939594.0000   2939565.0000
# mean        0.4489        0.0000       859.2077       860.0021       860.0029
# std         0.0189        0.0000         3.6477         0.5578         0.3518
# min         0.0051        0.0000       840.2980       855.9290       858.2800
# 25%         0.4484        0.0000       857.9490       859.7760       859.8290
# 50%         0.4501        0.0000       859.5750       860.0220       860.0020
# 75%         0.4517        0.0000       860.2580       860.2490       860.1720
# max         0.9091        0.0000       877.2280       866.0340       870.1190
#
#        소입로 온도 4 Zone  솔트 컨베이어 온도 1 Zone  솔트 컨베이어 온도 2 Zone  솔트조 온도 1 Zone  \
# count   2939552.0000       2939616.0000       2939580.0000   2939513.0000
# mean        860.0062           283.9963           279.9293       331.8062
# std           0.4552             9.5128             6.6116         0.7827
# min         857.9920           266.2300           266.4260       328.1610
# 25%         859.8430           274.7540           273.5020       331.8670
# 50%         860.0000           284.5860           280.0200       332.0170
# 75%         860.1580           293.3430           286.3340       332.1410
# max         882.1480           298.5300           291.6960       332.7170
#
#        솔트조 온도 2 Zone
# count   2939519.0000
# mean        332.1773
# std           0.8733
# min         328.0730
# 25%         332.1780
# 50%         332.4230
# 75%         332.6260
# max         333.1790

# %% [markdown]
# ## 데이터 타입 확인

# %%
# 데이터의 기본 정보 확인
df.dtypes
# Out:
# TAG_MIN               object
# 배정번호                   int64
# 건조 1존 OP             float64
# 건조 2존 OP             float64
# 건조로 온도 1 Zone        float64
# 건조로 온도 2 Zone        float64
# 세정기                  float64
# 소입1존 OP              float64
# 소입2존 OP              float64
# 소입3존 OP              float64
# 소입4존 OP              float64
# 소입로 CP 값             float64
# 소입로 CP 모니터 값         float64
# 소입로 온도 1 Zone        float64
# 소입로 온도 2 Zone        float64
# 소입로 온도 3 Zone        float64
# 소입로 온도 4 Zone        float64
# 솔트 컨베이어 온도 1 Zone    float64
# 솔트 컨베이어 온도 2 Zone    float64
# 솔트조 온도 1 Zone        float64
# 솔트조 온도 2 Zone        float64
# dtype: object

# %% [markdown]
# # 데이터 정제(전처리)

# %% [markdown]
# ## 데이터의 타입 변경

# %%
# 날짜 데이터 형식 변환
df['TAG_MIN'] = pd.to_datetime(df.TAG_MIN, format = '%Y-%m-%d %H:%M:%S')

# %%
# 날짜 데이터 형식 변환 후, 데이터 타입 확인
df.dtypes
# Out:
# TAG_MIN              datetime64[ns]
# 배정번호                          int64
# 건조 1존 OP                    float64
# 건조 2존 OP                    float64
# 건조로 온도 1 Zone               float64
# 건조로 온도 2 Zone               float64
# 세정기                         float64
# 소입1존 OP                     float64
# 소입2존 OP                     float64
# 소입3존 OP                     float64
# 소입4존 OP                     float64
# 소입로 CP 값                    float64
# 소입로 CP 모니터 값                float64
# 소입로 온도 1 Zone               float64
# 소입로 온도 2 Zone               float64
# 소입로 온도 3 Zone               float64
# 소입로 온도 4 Zone               float64
# 솔트 컨베이어 온도 1 Zone           float64
# 솔트 컨베이어 온도 2 Zone           float64
# 솔트조 온도 1 Zone               float64
# 솔트조 온도 2 Zone               float64
# dtype: object

# %% [markdown]
# ## 결측치 처리

# %%
# 결측치 개수 확인
df.isnull().sum()
# Out:
# TAG_MIN                 0
# 배정번호                    0
# 건조 1존 OP                1
# 건조 2존 OP                1
# 건조로 온도 1 Zone         116
# 건조로 온도 2 Zone         148
# 세정기                    91
# 소입1존 OP              4288
# 소입2존 OP                 0
# 소입3존 OP                 2
# 소입4존 OP                 3
# 소입로 CP 값                1
# 소입로 CP 모니터 값          147
# 소입로 온도 1 Zone         130
# 소입로 온도 2 Zone         128
# 소입로 온도 3 Zone         157
# 소입로 온도 4 Zone         170
# 솔트 컨베이어 온도 1 Zone     106
# 솔트 컨베이어 온도 2 Zone     142
# 솔트조 온도 1 Zone         209
# 솔트조 온도 2 Zone         203
# dtype: int64

# %%
# 시간 순으로 정렬
df = df.sort_values(by = ['배정번호', 'TAG_MIN'])

# 아래에서 위 방향으로 채우기
df = df.fillna(method = 'bfill')

# %%
# 결측치 처리 결과 확인
df.isnull().sum()
# Out:
# TAG_MIN              0
# 배정번호                 0
# 건조 1존 OP             0
# 건조 2존 OP             0
# 건조로 온도 1 Zone        0
# 건조로 온도 2 Zone        0
# 세정기                  0
# 소입1존 OP              0
# 소입2존 OP              0
# 소입3존 OP              0
# 소입4존 OP              0
# 소입로 CP 값             0
# 소입로 CP 모니터 값         0
# 소입로 온도 1 Zone        0
# 소입로 온도 2 Zone        0
# 소입로 온도 3 Zone        0
# 소입로 온도 4 Zone        0
# 솔트 컨베이어 온도 1 Zone    0
# 솔트 컨베이어 온도 2 Zone    0
# 솔트조 온도 1 Zone        0
# 솔트조 온도 2 Zone        0
# dtype: int64

# %% [markdown]
# ## 불필요한 열 제거

# %%
# 변수별 unique 값 개수 확인
for col in df.columns:
    print(col, ':', len(df[col].value_counts()))
# Out:
# TAG_MIN : 2939722
# 배정번호 : 136
# 건조 1존 OP : 276048
# 건조 2존 OP : 357466
# 건조로 온도 1 Zone : 24556
# 건조로 온도 2 Zone : 20972
# 세정기 : 87471
# 소입1존 OP : 698624
# 소입2존 OP : 281506
# 소입3존 OP : 190100
# 소입4존 OP : 181396
# 소입로 CP 값 : 81025
# 소입로 CP 모니터 값 : 8269
# 소입로 온도 1 Zone : 39878
# 소입로 온도 2 Zone : 9475
# 소입로 온도 3 Zone : 6036
# 소입로 온도 4 Zone : 6579
# 솔트 컨베이어 온도 1 Zone : 42504
# 솔트 컨베이어 온도 2 Zone : 31365
# 솔트조 온도 1 Zone : 4907
# 솔트조 온도 2 Zone : 5808

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ## 히스토그램

# %%
import matplotlib.pyplot as plt

# 데이터 시각화 : 히스토그램
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize = (8, 5))
plt.hist(df['소입로 온도 2 Zone'], bins = 10)
plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlabel('소입로 2 Zone의 온도')
plt.ylabel('Count')
plt.title('소입로 온도 2 Zone', fontsize = 15)
plt.tight_layout()

# %% [markdown]
# ## 막대그래프

# %%
sns.barplot(data = df, x = '배정번호', y = '건조 1존 OP')
# Out:
# <Axes: xlabel='배정번호', ylabel='건조 1존 OP'>

# %% [markdown]
# ## 박스플롯

# %%
# 데이터 시각화 : 박스플롯
plt.figure(figsize = (10, 6))
plt.boxplot(df['소입로 온도 2 Zone'], vert = False)
plt.title('소입로 온도 2 Zone 박스플롯')
plt.xlabel('소입로 2 Zone의 온도')
plt.yticks([1], ['소입로 온도 2 Zone'])
plt.tight_layout()

# %%
plt.figure(figsize = (15, 4))
sns.boxplot(data = df, x = '배정번호', y = '건조 1존 OP')
# Out:
# <Axes: xlabel='배정번호', ylabel='건조 1존 OP'>

# %% [markdown]
# ## 선 그래프

# %%
df['건조 1존 OP'].plot()
# Out:
# <Axes: >

# %%
# 데이터 시각화 : 선 그래프
fig, ax = plt.subplots(figsize = (20, 8))
ax.plot(df['TAG_MIN'], df['소입로 온도 2 Zone'], label = f'소입로 온도 2 Zone')
plt.xticks(rotation = 90)
plt.legend(loc = 'upper left', bbox_to_anchor = (1, 1), fontsize = 20)
plt.title('소입로 온도 2 Zone', fontsize = 20)
plt.xlabel('날짜')
plt.ylabel('소입로 2 Zone의 온도')
plt.tight_layout()

# %%
plt.figure(figsize = (10, 5))
sns.lineplot(data = df, x = '건조 1존 OP', y = '건조 2존 OP', hue = '배정번호')
plt.legend(loc = 'upper right', bbox_to_anchor = (1.3, 1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 2
#       1 plt.figure(figsize = (10, 5))
# ----> 2 sns.lineplot(data = df, x = '건조 1존 OP', y = '건조 2존 OP', hue = '배정번호')
#       3 plt.legend(loc = 'upper right', bbox_to_anchor = (1.3, 1))
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:441, in _LinePlotter.plot(self, ax, kws)
#     438     grouped = sub_data.groupby(orient, sort=self.sort)
#     439     # Could pass as_index=False instead of reset_index,
#     440     # but that fails on a corner case with older pandas.
# --> 441     sub_data = grouped.apply(agg, other).reset_index()
#     442 else:
#     443     sub_data[f"{other}min"] = np.nan
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     new_msg = (
#    1560         f"The operation {orig_func} failed on a column. If any error is "
#    1561         f"raised, this will raise an exception in a future version "
#    1562         f"of pandas. Drop these columns to avoid this warning."
#    1563     )
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#    1577     with self._group_selection_context():
#    1578         # GH#50538
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1592 @final
#    1593 def _python_apply_general(
#    1594     self,
#    (...)
#    1599     is_agg: bool = False,
#    1600 ) -> NDFrameT:
#    1601     """
#    1602     Apply function f in python space
#    1603
#    (...)
#    1627         data after applying f
#    1628     """
# -> 1629     values, mutated = self.grouper.apply(f, data, self.axis)
#    1630     if not_indexed_same is None:
#    1631         not_indexed_same = mutated or self.mutated
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1540, in GroupBy.apply.<locals>.f(g)
#    1537 @wraps(func)
#    1538 def f(g):
#    1539     with np.errstate(all="ignore"):
# -> 1540         return func(g, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_statistics.py:488, in EstimateAggregator.__call__(self, data, var)
#     486     estimate = self.estimator(vals)
#     487 else:
# --> 488     estimate = vals.agg(self.estimator)
#     490 # Options that produce no error bars
#     491 if self.error_method is None:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4605, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4602     func = dict(kwargs.items())
#    4604 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4605 result = op.agg()
#    4606 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1126, in SeriesApply.agg(self)
#    1125 def agg(self):
# -> 1126     result = super().agg()
#    1127     if result is None:
#    1128         f = self.f
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:169, in Apply.agg(self)
#     166 kwargs = self.kwargs
#     168 if isinstance(arg, str):
# --> 169     return self.apply_str()
#     171 if is_dict_like(arg):
#     172     return self.agg_dict_like()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:570, in Apply.apply_str(self)
#     568 func = getattr(obj, f, None)
#     569 if callable(func):
# --> 570     sig = inspect.getfullargspec(func)
#     571     arg_names = (*sig.args, *sig.kwonlyargs)
#     572     if self.axis != 0 and (
#     573         "axis" not in arg_names or f in ("corrwith", "mad", "skew")
#     574     ):
#
# File ~\anaconda3\Lib\inspect.py:1369, in getfullargspec(func)
#    1337 """Get the names and default values of a callable object's parameters.
#    1338
#    1339 A tuple of seven things is returned:
#    (...)
#    1350   - wrapper chains defined by __wrapped__ *not* unwrapped automatically
#    1351 """
#    1352 try:
#    1353     # Re: `skip_bound_arg=False`
#    1354     #
#    (...)
#    1366     # getfullargspec() historically ignored __wrapped__ attributes,
#    1367     # so we ensure that remains the case in 3.3+
# -> 1369     sig = _signature_from_callable(func,
#    1370                                    follow_wrapper_chains=False,
#    1371                                    skip_bound_arg=False,
#    1372                                    sigcls=Signature,
#    1373                                    eval_str=False)
#    1374 except Exception as ex:
#    1375     # Most of the times 'signature' will raise ValueError.
#    1376     # But, it can also raise AttributeError, and, maybe something
#    1377     # else. So to be fully backwards compatible, we catch all
#    1378     # possible exceptions here, and reraise a TypeError.
#    1379     raise TypeError('unsupported callable') from ex
#
# File ~\anaconda3\Lib\inspect.py:2454, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2449     raise TypeError('{!r} is not a callable object'.format(obj))
#    2451 if isinstance(obj, types.MethodType):
#    2452     # In this case we skip the first parameter of the underlying
#    2453     # function (usually `self` or `cls`).
# -> 2454     sig = _get_signature_of(obj.__func__)
#    2456     if skip_bound_arg:
#    2457         return _signature_bound_method(sig)
#
# File ~\anaconda3\Lib\inspect.py:2516, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2511             return sig.replace(parameters=new_params)
#    2513 if isfunction(obj) or _signature_is_functionlike(obj):
#    2514     # If it's a pure Python function, or an object that is duck type
#    2515     # of a Python function (Cython functions, for instance), then:
# -> 2516     return _signature_from_function(sigcls, obj,
#    2517                                     skip_bound_arg=skip_bound_arg,
#    2518                                     globals=globals, locals=locals, eval_str=eval_str)
#    2520 if _signature_is_builtin(obj):
#    2521     return _signature_from_builtin(sigcls, obj,
#    2522                                    skip_bound_arg=skip_bound_arg)
#
# File ~\anaconda3\Lib\inspect.py:2423, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2418     parameters.append(Parameter(name, annotation=annotation,
#    2419                                 kind=_VAR_KEYWORD))
#    2421 # Is 'func' is a pure Python function - don't validate the
#    2422 # parameters list (for correct order and defaults), it should be OK.
# -> 2423 return cls(parameters,
#    2424            return_annotation=annotations.get('return', _empty),
#    2425            __validate_parameters__=is_duck_function)
#
# File ~\anaconda3\Lib\inspect.py:3019, in Signature.__init__(self, parameters, return_annotation, __validate_parameters__)
#    3017             params[name] = param
#    3018     else:
# -> 3019         params = OrderedDict((param.name, param) for param in parameters)
#    3021 self._parameters = types.MappingProxyType(params)
#    3022 self._return_annotation = return_annotation
#
# File ~\anaconda3\Lib\inspect.py:3019, in <genexpr>(.0)
#    3017             params[name] = param
#    3018     else:
# -> 3019         params = OrderedDict((param.name, param) for param in parameters)
#    3021 self._parameters = types.MappingProxyType(params)
#    3022 self._return_annotation = return_annotation
#
# File ~\anaconda3\Lib\inspect.py:2739, in Parameter.name(self)
#    2736     self._default = state['_default']
#    2737     self._annotation = state['_annotation']
# -> 2739 @property
#    2740 def name(self):
#    2741     return self._name
#    2743 @property
#    2744 def default(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Scatter

# %%
sns.scatterplot(data = df, x = '건조 1존 OP', y = '건조 2존 OP')
# Out:
# <Axes: xlabel='건조 1존 OP', ylabel='건조 2존 OP'>

# %% [markdown]
# # 데이터 병합 및 종속변수 라벨링

# %% [markdown]
# ## 독립변수간의 상관관계를 파악

# %%
# 히트맵 옵션 설정
import matplotlib

# 음수 부호 미노출 오류 제거
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# 상관관계 히트맵
import seaborn as sns
plt.rcParams['font.size'] = 20
plt.rcParams['font.family'] = 'Malgun Gothic'
cmap = 'coolwarm'
target_cor = df.corr().loc[['건조 1존 OP', '건조 2존 OP', '건조로 온도 1 Zone',
                            '건조로 온도 2 Zone', '세정기', '소입1존 OP', '소입2존 OP', '소입3존 OP', '소입4존 OP',
                            '소입로 CP 값', '소입로 CP 모니터 값', '소입로 온도 1 Zone', '소입로 온도 2 Zone',
                            '소입로 온도 3 Zone', '소입로 온도 4 Zone', '솔트 컨베이어 온도 1 Zone',
                            '솔트 컨베이어 온도 2 Zone', '솔트조 온도 1 Zone', '솔트조 온도 2 Zone']]
# 겹치는 상관계수 제거, mask 정보 입력
# mask = np.triu(np.ones_like(target_cor, dtype = np.bool))
fig = plt.figure(figsize = (40, 20))
sns.heatmap(target_cor, 
            vmin = -1, vmax = 1,
            cmap = cmap, linewidths = .5,
           annot = True, fmt = '.2f', xticklabels = False, yticklabels = False)
plt.xticks(np.arange(0.5, len(target_cor.columns)+0.5, 1), target_cor.columns, size = 20, rotation = 90)
plt.yticks(np.arange(0.5, len(target_cor.index)+0.5, 1), target_cor.index, size = 20)
plt.tight_layout()

# %% [markdown]
# ## 상관계수가 높은 변수 제거

# %%
# 변수간의 선형성 파악 : Jointplot
col_x = '소입로 CP 모니터 값'
col_y = '소입로 온도 3 Zone'
plt.figure(figsize = (8, 8))
plt.rcParams['font.size'] = 14
g = sns.jointplot(x = col_x, y = col_y, data = df, kind = 'reg', height = 6)
g.set_axis_labels(col_x, col_y, fontsize = 15)
plt.tight_layout()

# %%
# 상관관계가 높은 변수 제거
df.drop(['소입로 CP 모니터 값', '솔트조 온도 2 Zone'], axis = 1, inplace = True)

# %% [markdown]
# ## 공정데이터와 품질데이터 연결

# %%
df['Date'] = df['TAG_MIN'].dt.strftime('%Y%m%d %H:%M')

# %%
df_minute = df.groupby(['배정번호', 'Date']).mean().reset_index()

# %%
df_min = df_minute.groupby('배정번호').min().drop(columns = 'Date')
df_min.columns = [i + '_min' for i in df_minute.columns[2:]]
df_min.reset_index(drop = False, inplace = True)
df_min
# Out:
#        배정번호  건조 1존 OP_min  건조 2존 OP_min  건조로 온도 1 Zone_min  건조로 온도 2 Zone_min  \
# 0    102410       58.9739       10.7938            97.9130            98.5301
# 1    102585       58.4149        7.8147            98.1299            98.6609
# 2    102930       56.3573       10.0498            97.8217            98.5620
# 3    103142       58.3780       10.4308            98.4043            98.2523
# 4    103675       57.3318       10.0781            97.8173            98.5772
# ..      ...           ...           ...                ...                ...
# 131  147292       57.8382        0.3470            98.7950            99.4199
# 132  147546       57.0834        4.7092            99.2747            99.0551
# 133  147982       57.7769        5.1269            99.1284            99.3871
# 134  147996       60.3376        2.5682            98.5172            98.6585
# 135  148069       53.7505        0.0110            98.3477            98.9857
#
#      세정기_min  소입1존 OP_min  소입2존 OP_min  소입3존 OP_min  소입4존 OP_min  \
# 0    68.4406       0.1753      54.5058      46.9765      62.8312
# 1    67.8087       0.0131      50.8612      48.7442      67.1133
# 2    67.4163       0.5754      39.1330      44.7962      60.7692
# 3    67.1883       2.1483      42.6727      47.6140      64.1062
# 4    67.9623       4.7944      41.6690      45.4255      63.7629
# ..       ...          ...          ...          ...          ...
# 131  68.5085       0.5023      51.5019      52.1234      68.2021
# 132  68.9439       1.8538      47.6249      51.7933      69.7283
# 133  66.7972       0.6428      48.0353      51.9498      68.5659
# 134  67.8701       1.1465      51.9320      52.1641      69.2893
# 135  67.0169       0.8520      48.1189      50.2668      68.5859
#
#      소입로 CP 값_min  소입로 온도 1 Zone_min  소입로 온도 2 Zone_min  소입로 온도 3 Zone_min  \
# 0          0.4359           847.7547           858.9690           859.4735
# 1          0.4432           851.1176           858.8685           859.1696
# 2          0.4081           850.1007           858.7716           859.2557
# 3          0.3969           852.2612           859.2678           859.3768
# 4          0.4410           849.8728           859.3458           859.3781
# ..            ...                ...                ...                ...
# 131        0.4390           852.5503           858.9623           859.3404
# 132        0.4431           855.5768           859.4751           859.1057
# 133        0.4382           852.0040           858.6583           858.9352
# 134        0.3960           851.7940           858.0220           859.1777
# 135        0.4229           851.1500           857.8282           859.1207
#
#      소입로 온도 4 Zone_min  솔트 컨베이어 온도 1 Zone_min  솔트 컨베이어 온도 2 Zone_min  \
# 0             858.5370               268.8620               270.2953
# 1             858.2666               268.9533               268.6529
# 2             858.4386               268.7786               268.5391
# 3             858.6200               267.7614               268.8451
# 4             858.4671               266.3247               270.4594
# ..                 ...                    ...                    ...
# 131           858.8744               270.2149               269.4231
# 132           859.0318               270.1610               269.5899
# 133           859.0780               270.0268               269.7996
# 134           858.8941               270.3331               269.5727
# 135           858.8211               270.7574               271.0285
#
#      솔트조 온도 1 Zone_min
# 0             328.7108
# 1             328.7669
# 2             328.7960
# 3             328.7598
# 4             328.8424
# ..                 ...
# 131           331.8306
# 132           331.6125
# 133           331.9069
# 134           331.6776
# 135           331.7314
#
# [136 rows x 18 columns]

# %%
df_max = df_minute.groupby('배정번호').max().drop(columns = 'Date')
df_max.columns = [i + '_min' for i in df_minute.columns[2:]]
df_max.reset_index(drop = False, inplace = True)
df_max
# Out:
#        배정번호  건조 1존 OP_min  건조 2존 OP_min  건조로 온도 1 Zone_min  건조로 온도 2 Zone_min  \
# 0    102410       80.8888       32.7423           101.6711           101.1890
# 1    102585       78.2477       25.4344           101.6820           101.2092
# 2    102930       78.5684       27.4222           101.9536           101.4112
# 3    103142       77.8035       28.6716           101.7221           101.3488
# 4    103675       80.7264       26.5501           102.0074           101.3339
# ..      ...           ...           ...                ...                ...
# 131  147292       74.6931        9.3524           101.3777           101.3173
# 132  147546       73.3003       21.1028           101.5692           101.4396
# 133  147982       73.9282       20.8909           101.4884           101.4140
# 134  147996       75.5970       23.4151           101.2101           101.0333
# 135  148069       75.5001       18.1892           102.0483           101.7595
#
#      세정기_min  소입1존 OP_min  소입2존 OP_min  소입3존 OP_min  소입4존 OP_min  \
# 0    71.1865     100.0000      63.3739      53.2175      78.7264
# 1    71.3239     100.0000      64.0839      56.2302      79.8281
# 2    71.2346     100.0000      51.8029      52.0113      76.2749
# 3    71.2552     100.0000      49.5400      53.8809      78.6764
# 4    71.0799     100.0000      47.9116      53.3408      79.1712
# ..       ...          ...          ...          ...          ...
# 131  71.0530     100.0000      62.3141      57.9526      79.2408
# 132  70.8805     100.0000      60.3633      59.1333      77.2782
# 133  71.0261     100.0000      62.0956      59.6191      78.1854
# 134  71.1569     100.0000      65.1570      60.3677      80.0718
# 135  71.1966     100.0000      66.8879      59.8748      82.7153
#
#      소입로 CP 값_min  소입로 온도 1 Zone_min  소입로 온도 2 Zone_min  소입로 온도 3 Zone_min  \
# 0          0.4961           870.4061           861.2189           860.8111
# 1          0.4683           870.8343           861.6888           860.7730
# 2          0.4636           869.5294           861.5322           860.9546
# 3          0.4667           869.8356           860.7016           860.6635
# 4          0.4598           871.9544           860.8760           861.0106
# ..            ...                ...                ...                ...
# 131        0.4673           868.5363           861.4286           860.4892
# 132        0.4590           871.5875           861.8936           860.5158
# 133        0.4677           869.2373           862.2876           860.6309
# 134        0.4574           867.3811           861.2463           861.1473
# 135        0.4608           871.3524           861.9251           861.3743
#
#      소입로 온도 4 Zone_min  솔트 컨베이어 온도 1 Zone_min  솔트 컨베이어 온도 2 Zone_min  \
# 0             861.9385               295.8820               288.3655
# 1             861.4657               296.3536               290.5941
# 2             861.7371               296.9325               289.8684
# 3             861.6616               296.5394               290.1262
# 4             862.0029               295.9068               287.7051
# ..                 ...                    ...                    ...
# 131           861.0620               297.4198               289.9195
# 132           860.4953               297.4833               289.8468
# 133           860.9464               296.9665               289.3087
# 134           861.0912               297.5224               290.3666
# 135           861.1258               297.9176               290.4224
#
#      솔트조 온도 1 Zone_min
# 0             329.2270
# 1             329.2433
# 2             329.3766
# 3             329.3371
# 4             329.2677
# ..                 ...
# 131           332.4504
# 132           332.4996
# 133           332.3881
# 134           332.4399
# 135           332.4816
#
# [136 rows x 18 columns]

# %%
# 배정번호별 각 변수들의 통계량 : 평균, 표준편차
df_stat = df_minute.groupby(['배정번호']).agg(['mean', 'std'])
df_stat
# Out:
#        건조 1존 OP        건조 2존 OP        건조로 온도 1 Zone        건조로 온도 2 Zone  \
#            mean    std     mean    std          mean    std          mean
# 배정번호
# 102410  72.2790 3.4140  21.4036 4.2195       99.9398 0.5893      100.0502
# 102585  72.2344 3.0858  18.6136 2.6641       99.9869 0.5129      100.0643
# 102930  70.7085 2.9737  20.9190 2.3555       99.9966 0.4713      100.0216
# 103142  72.4234 2.2699  22.2585 2.1404      100.0045 0.3318      100.0070
# 103675  72.7818 3.9335  21.8871 3.4620       99.9826 0.6521      100.0413
# ...         ...    ...      ...    ...           ...    ...           ...
# 147292  69.4910 2.8151   4.3873 2.2704      100.0184 0.3787      100.0790
# 147546  69.7025 2.3581  17.8049 2.8321      100.0244 0.3110      100.0048
# 147982  69.7889 2.8709  17.8857 3.2388      100.0274 0.3448      100.0255
# 147996  69.9893 3.3067  16.8831 5.1731       99.9921 0.3792      100.0015
# 148069  69.0415 3.5165   5.2480 5.4271      100.0331 0.4151      100.2484
#
#                   세정기         ... 소입로 온도 3 Zone        소입로 온도 4 Zone         \
#           std    mean    std  ...          mean    std          mean    std
# 배정번호                          ...
# 102410 0.4955 69.6031 0.8464  ...      860.0123 0.2797      860.0130 0.5502
# 102585 0.3581 69.5935 1.0643  ...      859.9907 0.2386      859.9910 0.4765
# 102930 0.3428 69.5282 1.0986  ...      859.9959 0.2382      860.0077 0.4126
# 103142 0.2569 69.5355 1.0634  ...      859.9971 0.1849      860.0035 0.2933
# 103675 0.4710 69.3165 0.9955  ...      860.0232 0.3162      860.0069 0.5689
# ...       ...     ...    ...  ...           ...    ...           ...    ...
# 147292 0.2709 69.6414 0.7647  ...      859.9958 0.2161      859.9946 0.3230
# 147546 0.2589 70.1266 0.4989  ...      859.9877 0.2032      859.9979 0.2012
# 147982 0.3206 69.6966 1.1388  ...      860.0010 0.2876      860.0032 0.3081
# 147996 0.3766 69.4659 1.0216  ...      860.0008 0.3210      859.9903 0.3389
# 148069 0.3810 69.5746 1.1096  ...      860.0062 0.3352      860.0042 0.3354
#
#        솔트 컨베이어 온도 1 Zone        솔트 컨베이어 온도 2 Zone        솔트조 온도 1 Zone
#                     mean    std              mean    std          mean    std
# 배정번호
# 102410          282.6523 9.3853          280.0979 6.0401      329.0173 0.1172
# 102585          282.7642 9.5190          279.7780 7.1752      328.9986 0.0944
# 102930          283.3454 9.6890          279.2893 6.6703      329.1335 0.1153
# 103142          282.8963 9.4997          279.2367 6.5327      329.0823 0.0916
# 103675          283.5173 9.7558          277.5625 5.3773      329.0119 0.0852
# ...                  ...    ...               ...    ...           ...    ...
# 147292          284.6439 9.2267          280.4278 6.6948      332.1840 0.1052
# 147546          284.2132 9.3223          279.9769 6.6200      332.1550 0.1703
# 147982          284.2213 9.2356          280.0035 6.5521      332.2093 0.0899
# 147996          284.7382 9.2737          280.5046 6.7771      332.1508 0.1550
# 148069          284.4339 9.2779          280.5518 6.4354      332.1645 0.1318
#
# [136 rows x 34 columns]

# %%
# 배정번호별 각 변수들의 통계량으로 변수 생성
chg_name = {'mean' : '_Avg', 'std' : '_Std'}
df_stat.columns = list(map(lambda x: x[0] + chg_name[x[1]], df_stat.columns))
df_stat.reset_index(drop = False, inplace = True)

# %%
# 배정번호별 각 변수들의 통계량 : 평균, 표준편차
df_stat
# Out:
#        배정번호  건조 1존 OP_Avg  건조 1존 OP_Std  건조 2존 OP_Avg  건조 2존 OP_Std  \
# 0    102410       72.2790        3.4140       21.4036        4.2195
# 1    102585       72.2344        3.0858       18.6136        2.6641
# 2    102930       70.7085        2.9737       20.9190        2.3555
# 3    103142       72.4234        2.2699       22.2585        2.1404
# 4    103675       72.7818        3.9335       21.8871        3.4620
# ..      ...           ...           ...           ...           ...
# 131  147292       69.4910        2.8151        4.3873        2.2704
# 132  147546       69.7025        2.3581       17.8049        2.8321
# 133  147982       69.7889        2.8709       17.8857        3.2388
# 134  147996       69.9893        3.3067       16.8831        5.1731
# 135  148069       69.0415        3.5165        5.2480        5.4271
#
#      건조로 온도 1 Zone_Avg  건조로 온도 1 Zone_Std  건조로 온도 2 Zone_Avg  \
# 0              99.9398             0.5893           100.0502
# 1              99.9869             0.5129           100.0643
# 2              99.9966             0.4713           100.0216
# 3             100.0045             0.3318           100.0070
# 4              99.9826             0.6521           100.0413
# ..                 ...                ...                ...
# 131           100.0184             0.3787           100.0790
# 132           100.0244             0.3110           100.0048
# 133           100.0274             0.3448           100.0255
# 134            99.9921             0.3792           100.0015
# 135           100.0331             0.4151           100.2484
#
#      건조로 온도 2 Zone_Std  세정기_Avg  ...  소입로 온도 3 Zone_Avg  소입로 온도 3 Zone_Std  \
# 0               0.4955  69.6031  ...           860.0123             0.2797
# 1               0.3581  69.5935  ...           859.9907             0.2386
# 2               0.3428  69.5282  ...           859.9959             0.2382
# 3               0.2569  69.5355  ...           859.9971             0.1849
# 4               0.4710  69.3165  ...           860.0232             0.3162
# ..                 ...      ...  ...                ...                ...
# 131             0.2709  69.6414  ...           859.9958             0.2161
# 132             0.2589  70.1266  ...           859.9877             0.2032
# 133             0.3206  69.6966  ...           860.0010             0.2876
# 134             0.3766  69.4659  ...           860.0008             0.3210
# 135             0.3810  69.5746  ...           860.0062             0.3352
#
#      소입로 온도 4 Zone_Avg  소입로 온도 4 Zone_Std  솔트 컨베이어 온도 1 Zone_Avg  \
# 0             860.0130             0.5502               282.6523
# 1             859.9910             0.4765               282.7642
# 2             860.0077             0.4126               283.3454
# 3             860.0035             0.2933               282.8963
# 4             860.0069             0.5689               283.5173
# ..                 ...                ...                    ...
# 131           859.9946             0.3230               284.6439
# 132           859.9979             0.2012               284.2132
# 133           860.0032             0.3081               284.2213
# 134           859.9903             0.3389               284.7382
# 135           860.0042             0.3354               284.4339
#
#      솔트 컨베이어 온도 1 Zone_Std  솔트 컨베이어 온도 2 Zone_Avg  솔트 컨베이어 온도 2 Zone_Std  \
# 0                   9.3853               280.0979                 6.0401
# 1                   9.5190               279.7780                 7.1752
# 2                   9.6890               279.2893                 6.6703
# 3                   9.4997               279.2367                 6.5327
# 4                   9.7558               277.5625                 5.3773
# ..                     ...                    ...                    ...
# 131                 9.2267               280.4278                 6.6948
# 132                 9.3223               279.9769                 6.6200
# 133                 9.2356               280.0035                 6.5521
# 134                 9.2737               280.5046                 6.7771
# 135                 9.2779               280.5518                 6.4354
#
#      솔트조 온도 1 Zone_Avg  솔트조 온도 1 Zone_Std
# 0             329.0173             0.1172
# 1             328.9986             0.0944
# 2             329.1335             0.1153
# 3             329.0823             0.0916
# 4             329.0119             0.0852
# ..                 ...                ...
# 131           332.1840             0.1052
# 132           332.1550             0.1703
# 133           332.2093             0.0899
# 134           332.1508             0.1550
# 135           332.1645             0.1318
#
# [136 rows x 35 columns]

# %%
# 품질 데이터 불러오기
heat_result = pd.read_excel('C:\\Users\\taek5\\Desktop\\TG\\SmartFactory\\data\\HeatTreatmentQualityAssurance\\quality.xlsx')
heat_result
# Out:
#        배정번호        작업일  공정명       설비명   양품수량  불량수량    총수량
# 0    102410 2022-01-03  열처리  열처리 염욕_1  15160     3  15163
# 1    102585 2022-01-03  열처리  열처리 염욕_1  29892    10  29902
# 2    102930 2022-01-04  열처리  열처리 염욕_1  59616    30  59646
# 3    103142 2022-01-05  열처리  열처리 염욕_1  74730    13  74743
# 4    103675 2022-01-06  열처리  열처리 염욕_1  14979     2  14981
# ..      ...        ...  ...       ...    ...   ...    ...
# 131  147292 2022-07-14  열처리  열처리 염욕_1  43765    12  43777
# 132  147546 2022-07-15  열처리  열처리 염욕_1  59957    16  59973
# 133  147982 2022-07-18  열처리  열처리 염욕_1  40981    12  40993
# 134  147996 2022-07-18  열처리  열처리 염욕_1  30239     9  30248
# 135  148069 2022-07-19  열처리  열처리 염욕_1  58778     0  58778
#
# [136 rows x 7 columns]

# %% [markdown]
# - 작업일에 대한 변수를 만들면 좋지 않을까?

# %%
# 품질 데이터 불필요한 변수 제거
heat_result.drop(['작업일', '공정명', '설비명', '양품수량'], axis = 1, inplace = True)

# %%
# 공정 데이터와 품질 데이터 병합
df_total = pd.merge(heat_result, df_stat, on = '배정번호', how = 'left')

# %%
df_total = pd.merge(df_total, df_min, on = '배정번호', how = 'left')

# %%
df_total = pd.merge(df_total, df_max, on = '배정번호', how = 'left')

# %%
# 병합 데이터 확인
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 0 to 135
# Data columns (total 71 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   배정번호                     136 non-null    int64
#  1   불량수량                     136 non-null    int64
#  2   총수량                      136 non-null    int64
#  3   건조 1존 OP_Avg             136 non-null    float64
#  4   건조 1존 OP_Std             136 non-null    float64
#  5   건조 2존 OP_Avg             136 non-null    float64
#  6   건조 2존 OP_Std             136 non-null    float64
#  7   건조로 온도 1 Zone_Avg        136 non-null    float64
#  8   건조로 온도 1 Zone_Std        136 non-null    float64
#  9   건조로 온도 2 Zone_Avg        136 non-null    float64
#  10  건조로 온도 2 Zone_Std        136 non-null    float64
#  11  세정기_Avg                  136 non-null    float64
#  12  세정기_Std                  136 non-null    float64
#  13  소입1존 OP_Avg              136 non-null    float64
#  14  소입1존 OP_Std              136 non-null    float64
#  15  소입2존 OP_Avg              136 non-null    float64
#  16  소입2존 OP_Std              136 non-null    float64
#  17  소입3존 OP_Avg              136 non-null    float64
#  18  소입3존 OP_Std              136 non-null    float64
#  19  소입4존 OP_Avg              136 non-null    float64
#  20  소입4존 OP_Std              136 non-null    float64
#  21  소입로 CP 값_Avg             136 non-null    float64
#  22  소입로 CP 값_Std             136 non-null    float64
#  23  소입로 온도 1 Zone_Avg        136 non-null    float64
#  24  소입로 온도 1 Zone_Std        136 non-null    float64
#  25  소입로 온도 2 Zone_Avg        136 non-null    float64
#  26  소입로 온도 2 Zone_Std        136 non-null    float64
#  27  소입로 온도 3 Zone_Avg        136 non-null    float64
#  28  소입로 온도 3 Zone_Std        136 non-null    float64
#  29  소입로 온도 4 Zone_Avg        136 non-null    float64
#  30  소입로 온도 4 Zone_Std        136 non-null    float64
#  31  솔트 컨베이어 온도 1 Zone_Avg    136 non-null    float64
#  32  솔트 컨베이어 온도 1 Zone_Std    136 non-null    float64
#  33  솔트 컨베이어 온도 2 Zone_Avg    136 non-null    float64
#  34  솔트 컨베이어 온도 2 Zone_Std    136 non-null    float64
#  35  솔트조 온도 1 Zone_Avg        136 non-null    float64
#  36  솔트조 온도 1 Zone_Std        136 non-null    float64
#  37  건조 1존 OP_min_x           136 non-null    float64
#  38  건조 2존 OP_min_x           136 non-null    float64
#  39  건조로 온도 1 Zone_min_x      136 non-null    float64
#  40  건조로 온도 2 Zone_min_x      136 non-null    float64
#  41  세정기_min_x                136 non-null    float64
#  42  소입1존 OP_min_x            136 non-null    float64
#  43  소입2존 OP_min_x            136 non-null    float64
#  44  소입3존 OP_min_x            136 non-null    float64
#  45  소입4존 OP_min_x            136 non-null    float64
#  46  소입로 CP 값_min_x           136 non-null    float64
#  47  소입로 온도 1 Zone_min_x      136 non-null    float64
#  48  소입로 온도 2 Zone_min_x      136 non-null    float64
#  49  소입로 온도 3 Zone_min_x      136 non-null    float64
#  50  소입로 온도 4 Zone_min_x      136 non-null    float64
#  51  솔트 컨베이어 온도 1 Zone_min_x  136 non-null    float64
#  52  솔트 컨베이어 온도 2 Zone_min_x  136 non-null    float64
#  53  솔트조 온도 1 Zone_min_x      136 non-null    float64
#  54  건조 1존 OP_min_y           136 non-null    float64
#  55  건조 2존 OP_min_y           136 non-null    float64
#  56  건조로 온도 1 Zone_min_y      136 non-null    float64
#  57  건조로 온도 2 Zone_min_y      136 non-null    float64
#  58  세정기_min_y                136 non-null    float64
#  59  소입1존 OP_min_y            136 non-null    float64
#  60  소입2존 OP_min_y            136 non-null    float64
#  61  소입3존 OP_min_y            136 non-null    float64
#  62  소입4존 OP_min_y            136 non-null    float64
#  63  소입로 CP 값_min_y           136 non-null    float64
#  64  소입로 온도 1 Zone_min_y      136 non-null    float64
#  65  소입로 온도 2 Zone_min_y      136 non-null    float64
#  66  소입로 온도 3 Zone_min_y      136 non-null    float64
#  67  소입로 온도 4 Zone_min_y      136 non-null    float64
#  68  솔트 컨베이어 온도 1 Zone_min_y  136 non-null    float64
#  69  솔트 컨베이어 온도 2 Zone_min_y  136 non-null    float64
#  70  솔트조 온도 1 Zone_min_y      136 non-null    float64
# dtypes: float64(68), int64(3)
# memory usage: 76.5 KB

# %% [markdown]
# ## 종속변수 라벨링

# %%
# 불량률 파생변수 생성
# 불량률 = (불량수량 / 전체수량) * 100
df_total['불량률'] = round(df_total['불량수량'] / df_total['총수량'] * 100, 3)

# %%
# 불량률 분포 파악
plt.figure(figsize = (10, 6))
plt.boxplot(df_total['불량률'], vert = False)
plt.title('불량률 박스플랫')
plt.yticks([1], ['불량률'])
plt.tight_layout()

# %%
# 불량률 3사분위수 값 확인
df_total['불량률'].describe()
# Out:
# count   136.0000
# mean      0.0370
# std       0.0482
# min       0.0000
# 25%       0.0127
# 50%       0.0220
# 75%       0.0460
# max       0.3690
# Name: 불량률, dtype: float64

# %%
# 불량단계 변수 생성
df_total.loc[df_total['불량률'] >= 0.046, '불량단계'] = '위험'
df_total.loc[df_total['불량률'] < 0.046, '불량단계'] = '안정'

# %%
df_total['불량단계'].value_counts()
# Out:
# 안정    101
# 위험     35
# Name: 불량단계, dtype: int64

# %% [markdown]
# # 데이터셋 분리 및 스케일링

# %% [markdown]
# ## 불필요한 변수 삭제

# %%
# 불필요한 변수 삭제
df_total.drop(['배정번호', '불량수량', '총수량', '불량률'], axis = 1, inplace = True)

# %% [markdown]
# ## 학습, 평가 데이터셋 분리

# %%
# 독립변수와 종속변수의 분리
X_num = df_total[['건조 1존 OP_Avg', '건조 1존 OP_Std', '건조 2존 OP_Avg', '건조 2존 OP_Std',
                  '건조로 온도 1 Zone_Avg', '건조로 온도 1 Zone_Std', '건조로 온도 2 Zone_Avg', '건조로 온도 2 Zone_Std', 
                  '세정기_Avg', '세정기_Std', '소입1존 OP_Avg', '소입1존 OP_Std', '소입2존 OP_Avg', '소입2존 OP_Std', 
                  '소입3존 OP_Avg', '소입3존 OP_Std', '소입4존 OP_Avg', '소입4존 OP_Std',
                  '소입로 CP 값_Avg', '소입로 CP 값_Std', '소입로 온도 1 Zone_Avg', '소입로 온도 1 Zone_Std', 
                  '소입로 온도 2 Zone_Avg', '소입로 온도 2 Zone_Std', '소입로 온도 3 Zone_Avg', '소입로 온도 3 Zone_Std',
                  '소입로 온도 4 Zone_Avg', '소입로 온도 4 Zone_Std', '솔트 컨베이어 온도 1 Zone_Avg', '솔트 컨베이어 온도 1 Zone_Std', 
                  '솔트 컨베이어 온도 2 Zone_Avg', '솔트 컨베이어 온도 2 Zone_Std', 
                  '솔트조 온도 1 Zone_Avg', '솔트조 온도 1 Zone_Std']]
y = df_total['불량단계']

# %%
# 종속변수를 0과 1의 수치형 변수로 인코드
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
# 변환된 label classes 확인
print(le.classes_)
# Out:
# ['안정' '위험']

# %%
# 학습 데이터와 테스트 데이터 분리
from sklearn.model_selection import train_test_split

X_train_select, X_test_select, y_train_select, y_test_select = train_test_split(X_num, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ## 데이터 스케일링

# %%
# 특성 표준화
from sklearn.preprocessing import StandardScaler

# 변형 객체 생성
scaler = StandardScaler()

# 학습 데이터 스케일링
X_train_scaled = scaler.fit_transform(X_train_select)

# 테스트 데이터의 스케일링
X_test_scaled = scaler.fit_transform(X_test_select)

# %% [markdown]
# # 주요 변수 선택

# %% [markdown]
# ## 변수 선택 기법

# %%
# 후진 제거법을 통한 변수 선택
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
rfe_selector = RFE(estimator = XGBClassifier(eval_metric = 'error'), n_features_to_select = 12, step = 10, verbose = 5)
rfe_selector.fit(X_train_scaled, y_train_select)
rfe_support = rfe_selector.get_support()
rfe_feature = X_num.loc[:, rfe_support].columns.tolist()
print(f'불량단계 예측 사용 변수 목록 : {rfe_feature}')
# Out:
# Fitting estimator with 34 features.
# Fitting estimator with 24 features.
# Fitting estimator with 14 features.
# 불량단계 예측 사용 변수 목록 : ['건조 1존 OP_Avg', '건조로 온도 1 Zone_Std', '건조로 온도 2 Zone_Avg', '소입1존 OP_Std', '소입3존 OP_Std', '소입로 CP 값_Avg', '소입로 온도 3 Zone_Avg', '솔트 컨베이어 온도 1 Zone_Avg', '솔트 컨베이어 온도 1 Zone_Std', '솔트 컨베이어 온도 2 Zone_Avg', '솔트조 온도 1 Zone_Avg', '솔트조 온도 1 Zone_Std']

# %% [markdown]
# ## 최종 변수 선택

# %%
# 최종 변수 선택
final_X = df_total[['건조 1존 OP_Avg', '건조로 온도 1 Zone_Std', '건조로 온도 2 Zone_Avg', 
                    '소입1존 OP_Std', '소입3존 OP_Std', '소입로 CP 값_Avg', 
                    '소입로 온도 3 Zone_Avg', '솔트 컨베이어 온도 1 Zone_Avg', '솔트 컨베이어 온도 1 Zone_Std', 
                    '솔트 컨베이어 온도 2 Zone_Avg', '솔트조 온도 1 Zone_Avg', '솔트조 온도 1 Zone_Std']]

# %% [markdown]
# # 모델 구축과 학습 및 결과 분석

# %% [markdown]
# ## 데이터 분리

# %%
# 학습 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(final_X, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ## 데이터 스케일링

# %%
# 데이터 표준화
# 변형 객체 생성
scaler = StandardScaler()

# 학습 데이터 스케일링
X_train_scaled = scaler.fit_transform(X_train)

# 테스트 데이터의 스케일링
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# ## GridSearchCV를 통한 하이퍼파라미터 튜닝

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import f1_score

# K FOLD 교차검증
kfold = KFold(n_splits = 5, shuffle = True, random_state = 1)

# 하이퍼 파라미터
parameters_xc = {'n_estimators' : [20, 50, 100, 150, 200, 250, 300],
                'learning_rate' : [0.001, 0.05, 0.1, 0.15, 0.2],
                'max_depth' : [2, 4, 6, 8, 10, 12, 14, 16]}

# 모델 생성
model_xc = GridSearchCV(XGBClassifier(eval_metric = 'error'), parameters_xc, cv = kfold, verbose = 1, n_jobs = -1)

# 모델 학습
model_xc.fit(X_train_scaled, y_train)
print(f'XGBoost best 파라미터:{model_xc.best_params_}')

# xgboost
best_model_xc = model_xc.best_estimator_
best_model_xc.fit(X_train_scaled, y_train)

# 모델 예측
y_pred_xc = best_model_xc.predict(X_test_scaled)
score_xc = f1_score(y_test, y_pred_xc, average = 'macro')
print(f'불량탐지 XGBOOST f1_score :', score_xc)
# Out:
# Fitting 5 folds for each of 280 candidates, totalling 1400 fits
# XGBoost best 파라미터:{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 50}
# 불량탐지 XGBOOST f1_score : 0.6690307328605201

# %% [markdown]
# ## 예측 결과 확인

# %%
# 혼동행렬을 통한 예측 결과 확인
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_xc)
class_names = ['안정', '위험']
fig = plt.figure(figsize = (5, 4))
ax = sns.heatmap(cm ,annot = True, cmap = 'Blues', linewidths = 1, fmt = 'd',
                xticklabels = ['안정', '위험'], yticklabels = ['안정', '위험'])
ax.set(title = 'Confusion Matrix',
      ylabel = 'True label',
      xlabel = 'Predicted label')
plt.tight_layout()

# %%
from sklearn.metrics import classification_report
y_pred_xc = best_model_xc.predict(X_test_scaled)
print(classification_report(y_test, y_pred_xc, target_names = ['안정', '위험']))
# Out:
#               precision    recall  f1-score   support
#
#           안정       0.88      0.91      0.89        23
#           위험       0.50      0.40      0.44         5
#
#     accuracy                           0.82        28
#    macro avg       0.69      0.66      0.67        28
# weighted avg       0.81      0.82      0.81        28
